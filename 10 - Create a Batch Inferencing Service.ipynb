# %% [markdown]
# # Create a Batch Inferencing Service
#
# Imagine a health clinic takes patient measurements all day, saving the details for each patient in a separate file. Then overnight, the diabetes prediction model can be used to process all of the day's patient data as a batch, generating predictions that will be waiting the following morning so that the clinic can follow up with patients who are predicted to be at risk of diabetes. With Azure Machine Learning, you can accomplish this by creating a *batch inferencing pipeline*; and that's what you'll implement in this exercise.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

# Load the workspace from the saved config file
ws = Workspace.from_config(".\\Working_Files\\config.json")
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))
# Out:
# Ready to use Azure ML 1.24.0 to work with AML

# %% [markdown]
# ## Train and register a model
#
# Now let's train and register a model to deploy in a batch inferencing pipeline.

# %%
from azureml.core import Experiment
from azureml.core import Model
import pandas as pd
import numpy as np
import joblib
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve

# Create an Azure ML experiment in your workspace
experiment = Experiment(workspace=ws, name='mslearn-train-diabetes')
run = experiment.start_logging()
print("Starting experiment:", experiment.name)

# load the diabetes dataset
print("Loading Data...")
diabetes = pd.read_csv('data/diabetes.csv')

# Separate features and labels
X, y = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].values, diabetes['Diabetic'].values

# Split data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# Train a decision tree model
print('Training a decision tree model')
model = DecisionTreeClassifier().fit(X_train, y_train)

# calculate accuracy
y_hat = model.predict(X_test)
acc = np.average(y_hat == y_test)
print('Accuracy:', acc)
run.log('Accuracy', np.float(acc))

# calculate AUC
y_scores = model.predict_proba(X_test)
auc = roc_auc_score(y_test,y_scores[:,1])
print('AUC: ' + str(auc))
run.log('AUC', np.float(auc))

# Save the trained model
model_file = 'diabetes_model.pkl'
joblib.dump(value=model, filename=model_file)
run.upload_file(name = 'outputs/' + model_file, path_or_stream = './' + model_file)

# Complete the run
run.complete()

# Register the model
run.register_model(model_path='outputs/diabetes_model.pkl', model_name='diabetes_model',
                   tags={'Training context':'Inline Training'},
                   properties={'AUC': run.get_metrics()['AUC'], 'Accuracy': run.get_metrics()['Accuracy']})

print('Model trained and registered.')
# Out:
# Starting experiment: mslearn-train-diabetes
# Loading Data...
# Training a decision tree model
# Accuracy: 0.8896666666666667
# AUC: 0.8770958754166873
# Model trained and registered.

# %% [markdown]
# ## Generate and upload batch data
#
# Since we don't actually have a fully staffed clinic with patients from whom to get new data for this exercise, you'll generate a random sample from our diabetes CSV file, upload that data to a datastore in the Azure Machine Learning workspace, and register a dataset for it.

# %%
from azureml.core import Datastore, Dataset
import pandas as pd
import os

# Set default data store
ws.set_default_datastore('workspaceblobstore')
default_ds = ws.get_default_datastore()

# Enumerate all datastores, indicating which is the default
for ds_name in ws.datastores:
    print(ds_name, "- Default =", ds_name == default_ds.name)

# Load the diabetes data
diabetes = pd.read_csv('data/diabetes2.csv')
# Get a 100-item sample of the feature columns (not the diabetic label)
sample = diabetes[['Pregnancies','PlasmaGlucose','DiastolicBloodPressure','TricepsThickness','SerumInsulin','BMI','DiabetesPedigree','Age']].sample(n=100).values

# Create a folder
batch_folder = './batch-data'
os.makedirs(batch_folder, exist_ok=True)
print("Folder created!")

# Save each sample as a separate file
print("Saving files...")
for i in range(100):
    fname = str(i+1) + '.csv'
    sample[i].tofile(os.path.join(batch_folder, fname), sep=",")
print("files saved!")

# Upload the files to the default datastore
print("Uploading files to datastore...")
default_ds = ws.get_default_datastore()
default_ds.upload(src_dir="batch-data", target_path="batch-data", overwrite=True, show_progress=True)

# Register a dataset for the input data
batch_data_set = Dataset.File.from_files(path=(default_ds, 'batch-data/'), validate=False)
try:
    batch_data_set = batch_data_set.register(workspace=ws, 
                                             name='batch-data',
                                             description='batch data',
                                             create_new_version=True)
except Exception as ex:
    print(ex)

print("Done!")
# Out:
# azureml_globaldatasets - Default = False
# workspacefilestore - Default = False
# workspaceblobstore - Default = True
# Folder created!
# Saving files...
# files saved!
# Uploading files to datastore...
# Uploading an estimated of 100 files
# Uploading batch-data\1.csv
# Uploaded batch-data\1.csv, 1 files out of an estimated total of 100
# Uploading batch-data\10.csv
# Uploaded batch-data\10.csv, 2 files out of an estimated total of 100
# Uploading batch-data\100.csv
# Uploaded batch-data\100.csv, 3 files out of an estimated total of 100
# Uploading batch-data\11.csv
# Uploaded batch-data\11.csv, 4 files out of an estimated total of 100
# Uploading batch-data\12.csv
# Uploaded batch-data\12.csv, 5 files out of an estimated total of 100
# Uploading batch-data\13.csv
# Uploaded batch-data\13.csv, 6 files out of an estimated total of 100
# Uploading batch-data\14.csv
# Uploaded batch-data\14.csv, 7 files out of an estimated total of 100
# Uploading batch-data\15.csv
# Uploaded batch-data\15.csv, 8 files out of an estimated total of 100
# Uploading batch-data\16.csv
# Uploaded batch-data\16.csv, 9 files out of an estimated total of 100
# Uploading batch-data\17.csv
# Uploaded batch-data\17.csv, 10 files out of an estimated total of 100
# Uploading batch-data\18.csv
# Uploaded batch-data\18.csv, 11 files out of an estimated total of 100
# Uploading batch-data\19.csv
# Uploaded batch-data\19.csv, 12 files out of an estimated total of 100
# Uploading batch-data\2.csv
# Uploaded batch-data\2.csv, 13 files out of an estimated total of 100
# Uploading batch-data\20.csv
# Uploaded batch-data\20.csv, 14 files out of an estimated total of 100
# Uploading batch-data\21.csv
# Uploaded batch-data\21.csv, 15 files out of an estimated total of 100
# Uploading batch-data\22.csv
# Uploaded batch-data\22.csv, 16 files out of an estimated total of 100
# Uploading batch-data\23.csv
# Uploaded batch-data\23.csv, 17 files out of an estimated total of 100
# Uploading batch-data\24.csv
# Uploaded batch-data\24.csv, 18 files out of an estimated total of 100
# Uploading batch-data\25.csv
# Uploaded batch-data\25.csv, 19 files out of an estimated total of 100
# Uploading batch-data\26.csv
# Uploaded batch-data\26.csv, 20 files out of an estimated total of 100
# Uploading batch-data\27.csv
# Uploaded batch-data\27.csv, 21 files out of an estimated total of 100
# Uploading batch-data\28.csv
# Uploaded batch-data\28.csv, 22 files out of an estimated total of 100
# Uploading batch-data\29.csv
# Uploaded batch-data\29.csv, 23 files out of an estimated total of 100
# Uploading batch-data\3.csv
# Uploaded batch-data\3.csv, 24 files out of an estimated total of 100
# Uploading batch-data\30.csv
# Uploaded batch-data\30.csv, 25 files out of an estimated total of 100
# Uploading batch-data\31.csv
# Uploaded batch-data\31.csv, 26 files out of an estimated total of 100
# Uploading batch-data\32.csv
# Uploaded batch-data\32.csv, 27 files out of an estimated total of 100
# Uploading batch-data\33.csv
# Uploaded batch-data\33.csv, 28 files out of an estimated total of 100
# Uploading batch-data\34.csv
# Uploaded batch-data\34.csv, 29 files out of an estimated total of 100
# Uploading batch-data\35.csv
# Uploaded batch-data\35.csv, 30 files out of an estimated total of 100
# Uploading batch-data\36.csv
# Uploaded batch-data\36.csv, 31 files out of an estimated total of 100
# Uploading batch-data\37.csv
# Uploaded batch-data\37.csv, 32 files out of an estimated total of 100
# Uploading batch-data\38.csv
# Uploaded batch-data\38.csv, 33 files out of an estimated total of 100
# Uploading batch-data\39.csv
# Uploaded batch-data\39.csv, 34 files out of an estimated total of 100
# Uploading batch-data\4.csv
# Uploaded batch-data\4.csv, 35 files out of an estimated total of 100
# Uploading batch-data\40.csv
# Uploaded batch-data\40.csv, 36 files out of an estimated total of 100
# Uploading batch-data\41.csv
# Uploaded batch-data\41.csv, 37 files out of an estimated total of 100
# Uploading batch-data\42.csv
# Uploaded batch-data\42.csv, 38 files out of an estimated total of 100
# Uploading batch-data\43.csv
# Uploaded batch-data\43.csv, 39 files out of an estimated total of 100
# Uploading batch-data\44.csv
# Uploaded batch-data\44.csv, 40 files out of an estimated total of 100
# Uploading batch-data\45.csv
# Uploaded batch-data\45.csv, 41 files out of an estimated total of 100
# Uploading batch-data\46.csv
# Uploaded batch-data\46.csv, 42 files out of an estimated total of 100
# Uploading batch-data\47.csv
# Uploaded batch-data\47.csv, 43 files out of an estimated total of 100
# Uploading batch-data\48.csv
# Uploaded batch-data\48.csv, 44 files out of an estimated total of 100
# Uploading batch-data\49.csv
# Uploaded batch-data\49.csv, 45 files out of an estimated total of 100
# Uploading batch-data\5.csv
# Uploaded batch-data\5.csv, 46 files out of an estimated total of 100
# Uploading batch-data\50.csv
# Uploaded batch-data\50.csv, 47 files out of an estimated total of 100
# Uploading batch-data\51.csv
# Uploaded batch-data\51.csv, 48 files out of an estimated total of 100
# Uploading batch-data\52.csv
# Uploaded batch-data\52.csv, 49 files out of an estimated total of 100
# Uploading batch-data\53.csv
# Uploaded batch-data\53.csv, 50 files out of an estimated total of 100
# Uploading batch-data\54.csv
# Uploaded batch-data\54.csv, 51 files out of an estimated total of 100
# Uploading batch-data\55.csv
# Uploaded batch-data\55.csv, 52 files out of an estimated total of 100
# Uploading batch-data\56.csv
# Uploaded batch-data\56.csv, 53 files out of an estimated total of 100
# Uploading batch-data\57.csv
# Uploaded batch-data\57.csv, 54 files out of an estimated total of 100
# Uploading batch-data\58.csv
# Uploaded batch-data\58.csv, 55 files out of an estimated total of 100
# Uploading batch-data\59.csv
# Uploaded batch-data\59.csv, 56 files out of an estimated total of 100
# Uploading batch-data\6.csv
# Uploaded batch-data\6.csv, 57 files out of an estimated total of 100
# Uploading batch-data\60.csv
# Uploaded batch-data\60.csv, 58 files out of an estimated total of 100
# Uploading batch-data\61.csv
# Uploaded batch-data\61.csv, 59 files out of an estimated total of 100
# Uploading batch-data\62.csv
# Uploaded batch-data\62.csv, 60 files out of an estimated total of 100
# Uploading batch-data\63.csv
# Uploaded batch-data\63.csv, 61 files out of an estimated total of 100
# Uploading batch-data\64.csv
# Uploaded batch-data\64.csv, 62 files out of an estimated total of 100
# Uploading batch-data\65.csv
# Uploaded batch-data\65.csv, 63 files out of an estimated total of 100
# Uploading batch-data\66.csv
# Uploaded batch-data\66.csv, 64 files out of an estimated total of 100
# Uploading batch-data\67.csv
# Uploaded batch-data\67.csv, 65 files out of an estimated total of 100
# Uploading batch-data\68.csv
# Uploaded batch-data\68.csv, 66 files out of an estimated total of 100
# Uploading batch-data\69.csv
# Uploaded batch-data\69.csv, 67 files out of an estimated total of 100
# Uploading batch-data\7.csv
# Uploaded batch-data\7.csv, 68 files out of an estimated total of 100
# Uploading batch-data\70.csv
# Uploaded batch-data\70.csv, 69 files out of an estimated total of 100
# Uploading batch-data\71.csv
# Uploaded batch-data\71.csv, 70 files out of an estimated total of 100
# Uploading batch-data\72.csv
# Uploaded batch-data\72.csv, 71 files out of an estimated total of 100
# Uploading batch-data\73.csv
# Uploaded batch-data\73.csv, 72 files out of an estimated total of 100
# Uploading batch-data\74.csv
# Uploaded batch-data\74.csv, 73 files out of an estimated total of 100
# Uploading batch-data\75.csv
# Uploaded batch-data\75.csv, 74 files out of an estimated total of 100
# Uploading batch-data\76.csv
# Uploaded batch-data\76.csv, 75 files out of an estimated total of 100
# Uploading batch-data\77.csv
# Uploaded batch-data\77.csv, 76 files out of an estimated total of 100
# Uploading batch-data\78.csv
# Uploaded batch-data\78.csv, 77 files out of an estimated total of 100
# Uploading batch-data\79.csv
# Uploaded batch-data\79.csv, 78 files out of an estimated total of 100
# Uploading batch-data\8.csv
# Uploaded batch-data\8.csv, 79 files out of an estimated total of 100
# Uploading batch-data\80.csv
# Uploaded batch-data\80.csv, 80 files out of an estimated total of 100
# Uploading batch-data\81.csv
# Uploaded batch-data\81.csv, 81 files out of an estimated total of 100
# Uploading batch-data\82.csv
# Uploaded batch-data\82.csv, 82 files out of an estimated total of 100
# Uploading batch-data\83.csv
# Uploaded batch-data\83.csv, 83 files out of an estimated total of 100
# Uploading batch-data\84.csv
# Uploaded batch-data\84.csv, 84 files out of an estimated total of 100
# Uploading batch-data\85.csv
# Uploaded batch-data\85.csv, 85 files out of an estimated total of 100
# Uploading batch-data\86.csv
# Uploaded batch-data\86.csv, 86 files out of an estimated total of 100
# Uploading batch-data\87.csv
# Uploaded batch-data\87.csv, 87 files out of an estimated total of 100
# Uploading batch-data\88.csv
# Uploaded batch-data\88.csv, 88 files out of an estimated total of 100
# Uploading batch-data\89.csv
# Uploaded batch-data\89.csv, 89 files out of an estimated total of 100
# Uploading batch-data\9.csv
# Uploaded batch-data\9.csv, 90 files out of an estimated total of 100
# Uploading batch-data\90.csv
# Uploaded batch-data\90.csv, 91 files out of an estimated total of 100
# Uploading batch-data\91.csv
# Uploaded batch-data\91.csv, 92 files out of an estimated total of 100
# Uploading batch-data\92.csv
# Uploaded batch-data\92.csv, 93 files out of an estimated total of 100
# Uploading batch-data\93.csv
# Uploaded batch-data\93.csv, 94 files out of an estimated total of 100
# Uploading batch-data\94.csv
# Uploaded batch-data\94.csv, 95 files out of an estimated total of 100
# Uploading batch-data\95.csv
# Uploaded batch-data\95.csv, 96 files out of an estimated total of 100
# Uploading batch-data\96.csv
# Uploaded batch-data\96.csv, 97 files out of an estimated total of 100
# Uploading batch-data\97.csv
# Uploaded batch-data\97.csv, 98 files out of an estimated total of 100
# Uploading batch-data\98.csv
# Uploaded batch-data\98.csv, 99 files out of an estimated total of 100
# Uploading batch-data\99.csv
# Uploaded batch-data\99.csv, 100 files out of an estimated total of 100
# Uploaded 100 files
# Done!

# %% [markdown]
# ## Create compute
#
# We'll need a compute context for the pipeline, so we'll use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "LC-ML-Cluster-1"

try:
    # Check for existing compute target
    inference_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        inference_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        inference_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.

# %% [markdown]
# ## Create a pipeline for batch inferencing
#
# Now we're ready to define the pipeline we'll use for batch inferencing. Our pipeline will need Python code to perform the batch inferencing, so let's create a folder where we can keep all the files used by the pipeline:

# %%
import os
# Create a folder for the experiment files
experiment_folder = 'batch_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# batch_pipeline

# %% [markdown]
# Now we'll create a Python script to do the actual work, and save it in the pipeline folder:

# %%
# %%writefile $experiment_folder/batch_diabetes.py
import os
import numpy as np
from azureml.core import Model
import joblib


def init():
    # Runs when the pipeline step is initialized
    global model

    # load the model
    model_path = Model.get_model_path('diabetes_model')
    model = joblib.load(model_path)


def run(mini_batch):
    # This runs for each batch
    resultList = []

    # process each file in the batch
    for f in mini_batch:
        # Read the comma-delimited data into an array
        data = np.genfromtxt(f, delimiter=',')
        # Reshape into a 2-dimensional array for prediction (model expects multiple items)
        prediction = model.predict(data.reshape(1, -1))
        # Append prediction to results
        resultList.append("{}: {}".format(os.path.basename(f), prediction[0]))
    return resultList
# Out:
# Writing batch_pipeline/batch_diabetes.py

# %% [markdown]
# Next we'll define a run context that includes the dependencies required by the script

# %%
from azureml.core import Environment
from azureml.core.runconfig import DEFAULT_CPU_IMAGE
from azureml.core.runconfig import CondaDependencies

# Add dependencies required by the model
# For scikit-learn models, you need scikit-learn
# For parallel pipeline steps, you need azureml-core and azureml-dataprep[fuse]
cd = CondaDependencies.create(conda_packages=['scikit-learn','pip'],
                              pip_packages=['azureml-defaults','azureml-core','azureml-dataprep[fuse]'])

batch_env = Environment(name='batch_environment')
batch_env.python.conda_dependencies = cd
batch_env.docker.enabled = True
batch_env.docker.base_image = DEFAULT_CPU_IMAGE
print('Configuration ready.')
# Out:
# Configuration ready.

# %% [markdown]
# You're going to use a pipeline to run the batch prediction script, generate predictions from the input data, and save the results as a text file in the output folder. To do this, you can use a **ParallelRunStep**, which enables the batch data to be processed in parallel and the results collated in a single output file named *parallel_run_step.txt*.

# %%
from azureml.pipeline.steps import ParallelRunConfig, ParallelRunStep
from azureml.pipeline.core import PipelineData

default_ds = ws.get_default_datastore()

output_dir = PipelineData(name='inferences', 
                          datastore=default_ds, 
                          output_path_on_compute='diabetes/results')

parallel_run_config = ParallelRunConfig(
    source_directory=experiment_folder,
    entry_script="batch_diabetes.py",
    mini_batch_size="5",
    error_threshold=10,
    output_action="append_row",
    environment=batch_env,
    compute_target=inference_cluster,
    node_count=2)

parallelrun_step = ParallelRunStep(
    name='batch-score-diabetes',
    parallel_run_config=parallel_run_config,
    inputs=[batch_data_set.as_named_input('diabetes_batch')],
    output=output_dir,
    arguments=[],
    allow_reuse=True
)

print('Steps defined')
# Out:
# Steps defined

# %% [markdown]
# Now it's time to put the step into a pipeline, and run it.
#
# > **Note**: This may take some time!

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline

pipeline = Pipeline(workspace=ws, steps=[parallelrun_step])
pipeline_run = Experiment(ws, 'mslearn-diabetes-batch').submit(pipeline)
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step batch-score-diabetes [189c86ea][627cce5c-42bb-4523-88bf-199d3fb41bb6], (This step will run and generate new outputs)
# Submitted PipelineRun 26b45430-816f-4c0f-ba40-9a1fa7e598d4
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/26b45430-816f-4c0f-ba40-9a1fa7e598d4?wsid=/subscriptions/a0d35038-9212-4eca-88f1-682726afa75c/resourcegroups/ML/workspaces/AML
# PipelineRunId: 26b45430-816f-4c0f-ba40-9a1fa7e598d4
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/26b45430-816f-4c0f-ba40-9a1fa7e598d4?wsid=/subscriptions/a0d35038-9212-4eca-88f1-682726afa75c/resourcegroups/ML/workspaces/AML
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
#
# StepRunId: 066d8ae7-bf96-4d5e-8067-0dd8517f8dd3
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3?wsid=/subscriptions/a0d35038-9212-4eca-88f1-682726afa75c/resourcegroups/ML/workspaces/AML
# StepRun( batch-score-diabetes ) Status: NotStarted
# StepRun( batch-score-diabetes ) Status: Queued
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/03/21 06:06:33 Downloading source code...
# 2021/03/21 06:06:34 Finished downloading source code
# 2021/03/21 06:06:35 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/03/21 06:06:35 Successfully set up Docker network: acb_default_network
# 2021/03/21 06:06:35 Setting up Docker configuration...
# 2021/03/21 06:06:36 Successfully set up Docker configuration
# 2021/03/21 06:06:36 Logging in to registry: 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io
# 2021/03/21 06:06:38 Successfully logged into 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io
# 2021/03/21 06:06:38 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/21 06:06:38 Scanning for dependencies...
# 2021/03/21 06:06:38 Successfully scanned dependencies
# 2021/03/21 06:06:38 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/18 : FROM mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210220.v1@sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a
# sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a: Pulling from azureml/intelmpi2018.3-ubuntu16.04
# 4007a89234b4: Already exists
# 5dfa26c6b9c9: Already exists
# 0ba7bf18aa40: Already exists
# 4c6ec688ebe3: Already exists
# a2874ccdee09: Pulling fs layer
# 84e6fa394f53: Pulling fs layer
# cde35e537c55: Pulling fs layer
# 08224915e098: Pulling fs layer
# 3e72e2b08f2a: Pulling fs layer
# 503a95eb7b7f: Pulling fs layer
# cac267f3f656: Pulling fs layer
# 9c9189719fce: Pulling fs layer
# 3e72e2b08f2a: Waiting
# 503a95eb7b7f: Waiting
# cac267f3f656: Waiting
# 9c9189719fce: Waiting
# 08224915e098: Waiting
# 84e6fa394f53: Verifying Checksum
# 84e6fa394f53: Download complete
# cde35e537c55: Verifying Checksum
# cde35e537c55: Download complete
# a2874ccdee09: Verifying Checksum
# a2874ccdee09: Download complete
# 08224915e098: Verifying Checksum
# 08224915e098: Download complete
# 3e72e2b08f2a: Verifying Checksum
# 3e72e2b08f2a: Download complete
# 503a95eb7b7f: Verifying Checksum
# 503a95eb7b7f: Download complete
# cac267f3f656: Verifying Checksum
# cac267f3f656: Download complete
# 9c9189719fce: Verifying Checksum
# 9c9189719fce: Download complete
# a2874ccdee09: Pull complete
# StepRun( batch-score-diabetes ) Status: Running
# 84e6fa394f53: Pull complete
# cde35e537c55: Pull complete
# 08224915e098: Pull complete
# 3e72e2b08f2a: Pull complete
# 503a95eb7b7f: Pull complete
# cac267f3f656: Pull complete
# 9c9189719fce: Pull complete
# Digest: sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a
# Status: Downloaded newer image for mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210220.v1@sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a
#  ---> b79635653e9e
# Step 2/18 : USER root
#  ---> Running in b03cd2815b3c
# Removing intermediate container b03cd2815b3c
#  ---> 0d1647b34999
# Step 3/18 : RUN mkdir -p $HOME/.cache
#  ---> Running in ba6e2deeb7e9
# Removing intermediate container ba6e2deeb7e9
#  ---> 9e0e687c7003
# Step 4/18 : WORKDIR /
#  ---> Running in a365144d9d95
# Removing intermediate container a365144d9d95
#  ---> 667f76cf9ae3
# Step 5/18 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> ca83aa8a40ca
# Step 6/18 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in f127ec1cbe76
# Removing intermediate container f127ec1cbe76
#  ---> 7cd70b990107
# Step 7/18 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> 3b68fc8fed9b
# Step 8/18 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 935cdff1673d
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ##9        |  29%
# scipy-1.5.2          | 18.5 MB   | #######6   |  76%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | ######5    |  66%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | #######7   |  77%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 3          |   3%
# mkl-2019.4           | 204.1 MB  | 7          |   7%
# mkl-2019.4           | 204.1 MB  | #1         |  11%
# mkl-2019.4           | 204.1 MB  | #4         |  15%
# mkl-2019.4           | 204.1 MB  | #8         |  18%
# mkl-2019.4           | 204.1 MB  | ##2        |  22%
# mkl-2019.4           | 204.1 MB  | ##6        |  26%
# mkl-2019.4           | 204.1 MB  | ###        |  30%
# mkl-2019.4           | 204.1 MB  | ###4       |  34%
# mkl-2019.4           | 204.1 MB  | ###8       |  38%
# mkl-2019.4           | 204.1 MB  | ####2      |  42%
# mkl-2019.4           | 204.1 MB  | ####5      |  46%
# mkl-2019.4           | 204.1 MB  | #####      |  50%
# mkl-2019.4           | 204.1 MB  | #####4     |  54%
# mkl-2019.4           | 204.1 MB  | #####8     |  58%
# mkl-2019.4           | 204.1 MB  | ######2    |  62%
# mkl-2019.4           | 204.1 MB  | ######6    |  67%
# mkl-2019.4           | 204.1 MB  | #######    |  71%
# mkl-2019.4           | 204.1 MB  | #######4   |  75%
# mkl-2019.4           | 204.1 MB  | #######8   |  79%
# mkl-2019.4           | 204.1 MB  | ########2  |  83%
# mkl-2019.4           | 204.1 MB  | ########6  |  87%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########5 |  95%
# mkl-2019.4           | 204.1 MB  | #########9 |  99%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | #7         |  17%
# python-3.6.2         | 27.0 MB   | ####6      |  46%
# python-3.6.2         | 27.0 MB   | #######7   |  77%
# python-3.6.2         | 27.0 MB   | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.ekaxv653.requirements.txt']
# Pip subprocess output:
# Collecting azureml-defaults
#   Downloading azureml_defaults-1.24.0-py3-none-any.whl (3.1 kB)
# Collecting azureml-core
#   Downloading azureml_core-1.24.0.post2-py3-none-any.whl (2.2 MB)
# Collecting azureml-dataprep[fuse]
#   Downloading azureml_dataprep-2.13.0-py3-none-any.whl (39.4 MB)
# Collecting flask==1.0.3
#   Downloading Flask-1.0.3-py2.py3-none-any.whl (92 kB)
# Collecting werkzeug<=1.0.1,>=0.16.1
#   Downloading Werkzeug-1.0.1-py2.py3-none-any.whl (298 kB)
# Collecting json-logging-py==0.2
#   Downloading json-logging-py-0.2.tar.gz (3.6 kB)
# Collecting gunicorn==19.9.0
#   Downloading gunicorn-19.9.0-py2.py3-none-any.whl (112 kB)
# Collecting azureml-dataset-runtime[fuse]~=1.24.0
#   Downloading azureml_dataset_runtime-1.24.0-py3-none-any.whl (3.4 kB)
# Collecting configparser==3.7.4
#   Downloading configparser-3.7.4-py2.py3-none-any.whl (22 kB)
# Collecting applicationinsights>=0.11.7
#   Downloading applicationinsights-0.11.9-py2.py3-none-any.whl (58 kB)
# Collecting azureml-model-management-sdk==1.0.1b6.post1
#   Downloading azureml_model_management_sdk-1.0.1b6.post1-py2.py3-none-any.whl (130 kB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.25.1-py2.py3-none-any.whl (61 kB)
# Collecting python-dateutil>=2.7.3
#   Downloading python_dateutil-2.8.1-py2.py3-none-any.whl (227 kB)
# Collecting azure-mgmt-keyvault<7.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-2.2.0-py2.py3-none-any.whl (89 kB)
# Collecting jmespath
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-12.1.0-py2.py3-none-any.whl (1.1 MB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting msrest>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting ruamel.yaml>=0.15.35
#   Downloading ruamel.yaml-0.16.13-py2.py3-none-any.whl (111 kB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Collecting ndg-httpsclient
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-2.8.0-py2.py3-none-any.whl (718 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting pytz
#   Downloading pytz-2021.1-py2.py3-none-any.whl (510 kB)
# Collecting urllib3>=1.23
#   Downloading urllib3-1.26.4-py2.py3-none-any.whl (153 kB)
# Collecting jsonpickle
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-common>=1.1.12
#   Downloading azure_common-1.1.26-py2.py3-none-any.whl (12 kB)
# Collecting msrestazure>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting SecretStorage
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting adal>=1.2.0
#   Downloading adal-1.2.6-py2.py3-none-any.whl (55 kB)
# Collecting contextlib2
#   Downloading contextlib2-0.6.0.post1-py2.py3-none-any.whl (9.8 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting pathspec
#   Downloading pathspec-0.8.1-py2.py3-none-any.whl (28 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.0.1-py3-none-any.whl (15 kB)
# Collecting docker
#   Downloading docker-4.4.4-py2.py3-none-any.whl (147 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.6-cp36-abi3-manylinux2014_x86_64.whl (3.2 MB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.20-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-native<33.0.0,>=32.0.0
#   Downloading azureml_dataprep_native-32.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting azureml-dataprep-rslex<1.12.0a,>=1.11.0dev0
#   Downloading azureml_dataprep_rslex-1.11.0-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting click>=5.1
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
# Collecting itsdangerous>=0.24
#   Downloading itsdangerous-1.1.0-py2.py3-none-any.whl (16 kB)
# Collecting Jinja2>=2.10
#   Downloading Jinja2-2.11.3-py2.py3-none-any.whl (125 kB)
# Requirement already satisfied, skipping upgrade: numpy!=1.19.3; sys_platform == "linux" in /azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2/lib/python3.6/site-packages (from azureml-dataset-runtime[fuse]~=1.24.0->azureml-defaults->-r /azureml-environment-setup/condaenv.ekaxv653.requirements.txt (line 1)) (1.19.1)
# Collecting pyarrow<2.0.0,>=0.17.0
#   Downloading pyarrow-1.0.1-cp36-cp36m-manylinux2014_x86_64.whl (17.3 MB)
# Collecting dill>=0.2.7.1
#   Downloading dill-0.3.3-py2.py3-none-any.whl (81 kB)
# Requirement already satisfied, skipping upgrade: six>=1.10 in /azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2/lib/python3.6/site-packages (from azureml-model-management-sdk==1.0.1b6.post1->azureml-defaults->-r /azureml-environment-setup/condaenv.ekaxv653.requirements.txt (line 1)) (1.15.0)
# Collecting pandas>=0.20.2
#   Downloading pandas-1.1.5-cp36-cp36m-manylinux1_x86_64.whl (9.5 MB)
# Collecting liac-arff>=2.1.1
#   Downloading liac-arff-2.5.0.tar.gz (13 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core->-r /azureml-environment-setup/condaenv.ekaxv653.requirements.txt (line 2)) (2020.6.20)
# Collecting idna<3,>=2.5
#   Downloading idna-2.10-py2.py3-none-any.whl (58 kB)
# Collecting chardet<5,>=3.0.2
#   Downloading chardet-4.0.0-py2.py3-none-any.whl (178 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.2-cp36-cp36m-manylinux1_x86_64.whl (549 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-3.7.3-py3-none-any.whl (12 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.6.0-py3-none-any.whl (45 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-0.58.0-py2.py3-none-any.whl (61 kB)
# Collecting cffi>=1.12
#   Downloading cffi-1.14.5-cp36-cp36m-manylinux1_x86_64.whl (401 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.5.0-py2.py3-none-any.whl (18 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.10.0-py2.py3-none-any.whl (60 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting azure-core<2.0.0,>=1.0.0
#   Downloading azure_core-1.12.0-py2.py3-none-any.whl (130 kB)
# Collecting MarkupSafe>=0.23
#   Downloading MarkupSafe-1.1.1-cp36-cp36m-manylinux2010_x86_64.whl (32 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.0-py2.py3-none-any.whl (147 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-3.7.4.3-py3-none-any.whl (22 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.4.1-py3-none-any.whl (5.2 kB)
# Collecting pycparser
#   Downloading pycparser-2.20-py2.py3-none-any.whl (112 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: json-logging-py, fusepy, liac-arff
#   Building wheel for json-logging-py (setup.py): started
#   Building wheel for json-logging-py (setup.py): finished with status 'done'
#   Created wheel for json-logging-py: filename=json_logging_py-0.2-py3-none-any.whl size=3924 sha256=22ed37ecfc43c4b00cb7f3b33ad91efb293dc7b69e3255675578c74e238c0b46
#   Stored in directory: /root/.cache/pip/wheels/e2/1d/52/535a274b9c2ce7d4064838f2bdb62013801281ef7d7f21e2ee
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=a1a29f24c03cbed071fea26322ce5b54471b6941ece63f96fe085ef94ec08629
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
#   Building wheel for liac-arff (setup.py): started
#   Building wheel for liac-arff (setup.py): finished with status 'done'
#   Created wheel for liac-arff: filename=liac_arff-2.5.0-py3-none-any.whl size=11730 sha256=632926448573118798f6d812fdcc1ea190033cc1ac73f105e1abd37a9f7b2d91
#   Stored in directory: /root/.cache/pip/wheels/53/ba/da/8562a6a6dbb428fd1ecc21053106df3948645cd991958f669b
# Successfully built json-logging-py fusepy liac-arff
# Installing collected packages: werkzeug, click, itsdangerous, MarkupSafe, Jinja2, flask, json-logging-py, idna, urllib3, chardet, requests, python-dateutil, oauthlib, requests-oauthlib, isodate, msrest, azure-common, pycparser, cffi, cryptography, PyJWT, adal, msrestazure, azure-mgmt-keyvault, jmespath, azure-mgmt-resource, azure-graphrbac, ruamel.yaml.clib, ruamel.yaml, pyopenssl, pyasn1, ndg-httpsclient, azure-mgmt-authorization, azure-mgmt-containerregistry, backports.weakref, backports.tempfile, pytz, typing-extensions, zipp, importlib-metadata, jsonpickle, jeepney, SecretStorage, contextlib2, azure-mgmt-storage, pathspec, websocket-client, docker, azureml-core, gunicorn, cloudpickle, distro, dotnetcore2, azureml-dataprep-native, msal, portalocker, msal-extensions, azure-core, azure-identity, azureml-dataprep-rslex, fusepy, azureml-dataprep, pyarrow, azureml-dataset-runtime, configparser, applicationinsights, dill, pandas, liac-arff, azureml-model-management-sdk, azureml-defaults
# Successfully installed Jinja2-2.11.3 MarkupSafe-1.1.1 PyJWT-2.0.1 SecretStorage-3.3.1 adal-1.2.6 applicationinsights-0.11.9 azure-common-1.1.26 azure-core-1.12.0 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-2.8.0 azure-mgmt-keyvault-2.2.0 azure-mgmt-resource-12.1.0 azure-mgmt-storage-11.2.0 azureml-core-1.24.0.post2 azureml-dataprep-2.13.0 azureml-dataprep-native-32.0.0 azureml-dataprep-rslex-1.11.0 azureml-dataset-runtime-1.24.0 azureml-defaults-1.24.0 azureml-model-management-sdk-1.0.1b6.post1 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.14.5 chardet-4.0.0 click-7.1.2 cloudpickle-1.6.0 configparser-3.7.4 contextlib2-0.6.0.post1 cryptography-3.4.6 dill-0.3.3 distro-1.5.0 docker-4.4.4 dotnetcore2-2.1.20 flask-1.0.3 fusepy-3.0.1 gunicorn-19.9.0 idna-2.10 importlib-metadata-3.7.3 isodate-0.6.0 itsdangerous-1.1.0 jeepney-0.6.0 jmespath-0.10.0 json-logging-py-0.2 jsonpickle-2.0.0 liac-arff-2.5.0 msal-1.10.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.0 pandas-1.1.5 pathspec-0.8.1 portalocker-1.7.1 pyarrow-1.0.1 pyasn1-0.4.8 pycparser-2.20 pyopenssl-20.0.1 python-dateutil-2.8.1 pytz-2021.1 requests-2.25.1 requests-oauthlib-1.3.0 ruamel.yaml-0.16.13 ruamel.yaml.clib-0.2.2 typing-extensions-3.7.4.3 urllib3-1.26.4 websocket-client-0.58.0 werkzeug-1.0.1 zipp-3.4.1
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.7.12
#   latest version: 4.9.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 935cdff1673d
#  ---> 07c1bde5b426
# Step 9/18 : ENV PATH /azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2/bin:$PATH
#  ---> Running in ef399db24adf
# Removing intermediate container ef399db24adf
#  ---> 6e0796ab1b2e
# Step 10/18 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> 5491d938a3bd
# Step 11/18 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 42c4c9e04e91
# Step 12/18 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2
#  ---> Running in 5bd72be9dc2f
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container 5bd72be9dc2f
#  ---> a57861c65411
# Step 13/18 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2
#  ---> Running in ea1876d4d6a6
# Removing intermediate container ea1876d4d6a6
#  ---> 4a71ad611581
# Step 14/18 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_15a07964bce25243e0b7e62a107037d2/lib:$LD_LIBRARY_PATH
#  ---> Running in 86c531fd32ce
# Removing intermediate container 86c531fd32ce
#  ---> 555a859c7b35
# Step 15/18 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> d8ce545e3f7c
# Step 16/18 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in f88d595e03e9
# Removing intermediate container f88d595e03e9
#  ---> 0283db2e0fb8
# Step 17/18 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 8eca5ffeec19
# Removing intermediate container 8eca5ffeec19
#  ---> 2ce1b800de70
# Step 18/18 : CMD ["bash"]
#  ---> Running in 25f36830cabc
# Removing intermediate container 25f36830cabc
#  ---> 822918bc0513
# Successfully built 822918bc0513
# Successfully tagged 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io/azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e:latest
# Successfully tagged 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io/azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e:1
# 2021/03/21 06:10:52 Successfully executed container: acb_step_0
# 2021/03/21 06:10:52 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/21 06:10:52 Pushing image: 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io/azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e:1, attempt 1
# The push refers to repository [05ae1289f7d6445289bee0b8433bc9bc.azurecr.io/azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e]
# f9a755c835ab: Preparing
# 9236caa08a05: Preparing
# a2d9a576ac3a: Preparing
# 3a97bbe1d049: Preparing
# f4a9c4c60c7f: Preparing
# dd0f7f5c60b2: Preparing
# 7c030d837446: Preparing
# 031c4813e5a2: Preparing
# dc6c8158d466: Preparing
# 303a8fd39764: Preparing
# 2d9074798077: Preparing
# 710fe8abc588: Preparing
# fcf8f624203c: Preparing
# 5b068a34ffe7: Preparing
# 51a74f86a3cf: Preparing
# 95474adf3c5c: Preparing
# 846cc75ad492: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# dd0f7f5c60b2: Waiting
# 7c030d837446: Waiting
# 031c4813e5a2: Waiting
# dc6c8158d466: Waiting
# 303a8fd39764: Waiting
# 2d9074798077: Waiting
# 710fe8abc588: Waiting
# fcf8f624203c: Waiting
# 5b068a34ffe7: Waiting
# 51a74f86a3cf: Waiting
# 95474adf3c5c: Waiting
# 846cc75ad492: Waiting
# 5276d2b930fc: Waiting
# e6feec0db89a: Waiting
# 697949baa658: Waiting
# 935c56d8b3f9: Waiting
# f9a755c835ab: Pushed
# 3a97bbe1d049: Pushed
# 9236caa08a05: Pushed
# a2d9a576ac3a: Pushed
# 7c030d837446: Pushed
# dd0f7f5c60b2: Pushed
# dc6c8158d466: Pushed
# 031c4813e5a2: Pushed
# 303a8fd39764: Pushed
# 2d9074798077: Pushed
# 710fe8abc588: Pushed
# 95474adf3c5c: Pushed
# fcf8f624203c: Pushed
# 5b068a34ffe7: Pushed
# 5276d2b930fc: Pushed
# 51a74f86a3cf: Pushed
# e6feec0db89a: Pushed
# 697949baa658: Pushed
# 846cc75ad492: Pushed
# 935c56d8b3f9: Pushed
#
# f4a9c4c60c7f: Pushed
# 1: digest: sha256:d147a876bfb5e2147dd4539ee5d1ca87f9790f7fe154716849bd6406f69ee030 size: 4721
# 2021/03/21 06:13:16 Successfully pushed image: 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io/azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e:1
# 2021/03/21 06:13:16 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/03/21 06:13:16 Pushing image: 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io/azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e:latest, attempt 1
# The push refers to repository [05ae1289f7d6445289bee0b8433bc9bc.azurecr.io/azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e]
# f9a755c835ab: Preparing
# 9236caa08a05: Preparing
# a2d9a576ac3a: Preparing
# 3a97bbe1d049: Preparing
# f4a9c4c60c7f: Preparing
# dd0f7f5c60b2: Preparing
# 7c030d837446: Preparing
# 031c4813e5a2: Preparing
# dc6c8158d466: Preparing
# 303a8fd39764: Preparing
# 2d9074798077: Preparing
# 710fe8abc588: Preparing
# fcf8f624203c: Preparing
# 5b068a34ffe7: Preparing
# 51a74f86a3cf: Preparing
# 95474adf3c5c: Preparing
# 846cc75ad492: Preparing
# 5276d2b930fc: Preparing
# e6feec0db89a: Preparing
# 697949baa658: Preparing
# 935c56d8b3f9: Preparing
# dd0f7f5c60b2: Waiting
# 7c030d837446: Waiting
# 031c4813e5a2: Waiting
# 5b068a34ffe7: Waiting
# 51a74f86a3cf: Waiting
# dc6c8158d466: Waiting
# 95474adf3c5c: Waiting
# 846cc75ad492: Waiting
# 303a8fd39764: Waiting
# 2d9074798077: Waiting
# 710fe8abc588: Waiting
# 5276d2b930fc: Waiting
# fcf8f624203c: Waiting
# e6feec0db89a: Waiting
# 935c56d8b3f9: Waiting
# 697949baa658: Waiting
# f4a9c4c60c7f: Layer already exists
# 9236caa08a05: Layer already exists
# f9a755c835ab: Layer already exists
# a2d9a576ac3a: Layer already exists
# 3a97bbe1d049: Layer already exists
# 031c4813e5a2: Layer already exists
# 7c030d837446: Layer already exists
# dd0f7f5c60b2: Layer already exists
# 303a8fd39764: Layer already exists
# 2d9074798077: Layer already exists
# dc6c8158d466: Layer already exists
# 95474adf3c5c: Layer already exists
# 51a74f86a3cf: Layer already exists
# fcf8f624203c: Layer already exists
# 710fe8abc588: Layer already exists
# 5b068a34ffe7: Layer already exists
# e6feec0db89a: Layer already exists
# 846cc75ad492: Layer already exists
# 5276d2b930fc: Layer already exists
# 935c56d8b3f9: Layer already exists
# 697949baa658: Layer already exists
# latest: digest: sha256:d147a876bfb5e2147dd4539ee5d1ca87f9790f7fe154716849bd6406f69ee030 size: 4721
# 2021/03/21 06:13:23 Successfully pushed image: 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io/azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e:latest
# 2021/03/21 06:13:23 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 254.796293)
# 2021/03/21 06:13:23 Populating digests for step ID: acb_step_0...
# 2021/03/21 06:13:27 Successfully populated digests for step ID: acb_step_0
# 2021/03/21 06:13:27 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 143.776104)
# 2021/03/21 06:13:27 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 7.113199)
# 2021/03/21 06:13:27 The following dependencies were found:
# 2021/03/21 06:13:27
# - image:
#     registry: 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io
#     repository: azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e
#     tag: latest
#     digest: sha256:d147a876bfb5e2147dd4539ee5d1ca87f9790f7fe154716849bd6406f69ee030
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210220.v1
#     digest: sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a
#   git: {}
# - image:
#     registry: 05ae1289f7d6445289bee0b8433bc9bc.azurecr.io
#     repository: azureml/azureml_32f224118c0c8455bd3934a22ccf1e5e
#     tag: "1"
#     digest: sha256:d147a876bfb5e2147dd4539ee5d1ca87f9790f7fe154716849bd6406f69ee030
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/intelmpi2018.3-ubuntu16.04
#     tag: 20210220.v1
#     digest: sha256:45f047999ab2ced61a2fd0cf8d8421f796ca05b8423c1a0ac652791a321bff9a
#   git: {}
#
# Run ID: cb5 was successful after 6m56s
# Streaming azureml-logs/55_azureml-execution-tvmps_23c651f995573302fb40760c1ba8c3fa2d3edb749b1e89c4e2c3bf189841fcaa_d.txt
# ========================================================================================================================
# 2021-03-21T06:18:07Z Starting output-watcher...
# 2021-03-21T06:18:07Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-03-21T06:18:08Z Executing 'Copy ACR Details file' on 10.0.0.7
# 2021-03-21T06:18:08Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-03-21T06:18:08Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# 2021-03-21T06:18:08Z Copy ACR Details file succeeded on 10.0.0.7. Output:
# >>>
# Login Succeeded
# Using default tag: latest
# latest: Pulling from azureml/azureml_1f3c26a22a7cca7ea03b17ac7d2bb0a6
# 4007a89234b4: Pulling fs layer
# 5dfa26c6b9c9: Pulling fs layer
# 0ba7bf18aa40: Pulling fs layer
# 4c6ec688ebe3: Pulling fs layer
# a2874ccdee09: Pulling fs layer
# 84e6fa394f53: Pulling fs layer
# cde35e537c55: Pulling fs layer
# 08224915e098: Pulling fs layer
# 3e72e2b08f2a: Pulling fs layer
# 503a95eb7b7f: Pulling fs layer
# cac267f3f656: Pulling fs layer
# 9c9189719fce: Pulling fs layer
# d75bfbbdd25f: Pulling fs layer
# 3babcc68ce0a: Pulling fs layer
# 7f5ff3a1dd4d: Pulling fs layer
# b363d6afae35: Pulling fs layer
# 9e11c0c2b5c5: Pulling fs layer
# 4c6ec688ebe3: Waiting
# a2874ccdee09: Waiting
# 84e6fa394f53: Waiting
# cde35e537c55: Waiting
# 08224915e098: Waiting
# 3e72e2b08f2a: Waiting
# 503a95eb7b7f: Waiting
# cac267f3f656: Waiting
# 9c9189719fce: Waiting
# d75bfbbdd25f: Waiting
# 3babcc68ce0a: Waiting
# 7f5ff3a1dd4d: Waiting
# b363d6afae35: Waiting
# 9e11c0c2b5c5: Waiting
# 5dfa26c6b9c9: Download complete
# 4c6ec688ebe3: Verifying Checksum
# 4c6ec688ebe3: Download complete
# 0ba7bf18aa40: Verifying Checksum
# 0ba7bf18aa40: Download complete
# 4007a89234b4: Verifying Checksum
# 4007a89234b4: Download complete
# 84e6fa394f53: Verifying Checksum
# 84e6fa394f53: Download complete
# cde35e537c55: Verifying Checksum
# cde35e537c55: Download complete
# 08224915e098: Verifying Checksum
# 08224915e098: Download complete
# a2874ccdee09: Verifying Checksum
# a2874ccdee09: Download complete
# cac267f3f656: Verifying Checksum
# cac267f3f656: Download complete
# 9c9189719fce: Verifying Checksum
# 9c9189719fce: Download complete
# 503a95eb7b7f: Verifying Checksum
# 503a95eb7b7f: Download complete
# 3babcc68ce0a: Verifying Checksum
# 3babcc68ce0a: Download complete
# 7f5ff3a1dd4d: Verifying Checksum
# 7f5ff3a1dd4d: Download complete
# b363d6afae35: Verifying Checksum
# b363d6afae35: Download complete
# 9e11c0c2b5c5: Verifying Checksum
# 9e11c0c2b5c5: Download complete
# 3e72e2b08f2a: Verifying Checksum
# 3e72e2b08f2a: Download complete
# 4007a89234b4: Pull complete
# 5dfa26c6b9c9: Pull complete
# 0ba7bf18aa40: Pull complete
# 4c6ec688ebe3: Pull complete
# d75bfbbdd25f: Verifying Checksum
# d75bfbbdd25f: Download complete
# a2874ccdee09: Pull complete
# 84e6fa394f53: Pull complete
# cde35e537c55: Pull complete
# 08224915e098: Pull complete
# 3e72e2b08f2a: Pull complete
# 503a95eb7b7f: Pull complete
# cac267f3f656: Pull complete
# 9c9189719fce: Pull complete
# d75bfbbdd25f: Pull complete
# 3babcc68ce0a: Pull complete
# 7f5ff3a1dd4d: Pull complete
# b363d6afae35: Pull complete
# 9e11c0c2b5c5: Pull complete
# Digest: sha256:9c1b3720e6155847eb0701e3285ffd89726766aea739759fc97e5d3b59db3313
# Status: Downloaded newer image for viennaglobal.azurecr.io/azureml/azureml_1f3c26a22a7cca7ea03b17ac7d2bb0a6:latest
# viennaglobal.azurecr.io/azureml/azureml_1f3c26a22a7cca7ea03b17ac7d2bb0a6:latest
# 2021-03-21T06:18:29Z Check if container 066d8ae7-bf96-4d5e-8067-0dd8517f8dd3 already exist exited with 0,
#
# 9ce6f52347a66b983d9d745f277a230e5ae32247d0b1e990e55cc2121c7973c4
# 2021/03/21 06:18:49 Starting App Insight Logger for task:  containerSetup
# 2021/03/21 06:18:49 Version: 3.0.01524.0008 Branch: .SourceBranch Commit: eba29f9
# 2021/03/21 06:18:49 Entered ContainerSetupTask - Preparing infiniband
# 2021/03/21 06:18:49 Starting infiniband setup
# 2021/03/21 06:18:49 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/03/21 06:18:49 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/03/21 06:18:49 Starting setupPasswordLessSSH setup
# 2021/03/21 06:18:49 sshd runtime has already been installed in the container
# 2021/03/21 06:18:49 All App Insights Logs was send successfully
# 2021/03/21 06:18:49 App Insight Client has already been closed
# 2021/03/21 06:18:49 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-03-21T06:18:49Z Starting docker container succeeded.
#
# Streaming azureml-logs/65_job_prep-tvmps_23c651f995573302fb40760c1ba8c3fa2d3edb749b1e89c4e2c3bf189841fcaa_d.txt
# ===============================================================================================================
# [2021-03-21T06:18:50.280648] Entering job preparation.
# [2021-03-21T06:18:51.738841] Starting job preparation.
# [2021-03-21T06:18:51.739281] Extracting the control code.
# [2021-03-21T06:18:51.760027] fetching and extracting the control code on master node.
# [2021-03-21T06:18:51.760396] Starting extract_project.
# [2021-03-21T06:18:51.760709] Starting to extract zip file.
# [2021-03-21T06:18:52.591493] Finished extracting zip file.
# [2021-03-21T06:18:52.775230] Using urllib.request Python 3.0 or later
# [2021-03-21T06:18:52.775343] Start fetching snapshots.
# [2021-03-21T06:18:52.775412] Start fetching snapshot.
# [2021-03-21T06:18:52.775448] Retrieving project from snapshot: 6a6b8504-4a70-4145-8d4e-f16a0ee50342
# Starting the daemon thread to refresh tokens in background for process with pid = 49
# [2021-03-21T06:18:53.198627] Finished fetching snapshot.
# [2021-03-21T06:18:53.198707] Start fetching snapshot.
# [2021-03-21T06:18:53.198735] Retrieving project from snapshot: c5b4c129-f7dd-45aa-98c9-cddfe1d7a1c3
# [2021-03-21T06:19:08.089796] Finished fetching snapshot.
# [2021-03-21T06:19:08.089835] Finished fetching snapshots.
# [2021-03-21T06:19:08.089845] Finished extract_project.
# [2021-03-21T06:19:08.105160] Finished fetching and extracting the control code.
# [2021-03-21T06:19:08.111628] Start run_history_prep.
# [2021-03-21T06:19:08.369492] Job preparation is complete.
# [2021-03-21T06:19:08.369969] Entering Data Context Managers in Sidecar
# [2021-03-21T06:19:08.371336] Running Sidecar prep cmd...
# [2021-03-21T06:19:08.445051] INFO azureml.sidecar.sidecar: Received task: enter_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/mounts/workspaceblobstore/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3
# [2021-03-21T06:19:08.445757] INFO azureml.sidecar.sidecar: Invoking "enter_contexts" task with Context Managers: {"context_managers": ["Dataset:context_managers.Datasets", "DataStoreCopy:context_managers.DataStores"]}
# Enter __enter__ of DatasetContextManager
# SDK version: azureml-core==1.22.0 azureml-dataprep==2.10.1. Session id: a02f3999-b8d4-4da5-b4e3-f61855c4f9f4. Run id: 066d8ae7-bf96-4d5e-8067-0dd8517f8dd3.
# Processing 'diabetes_batch'.
# Processing dataset FileDataset
# {
#   "source": [
#     "('workspaceblobstore', 'batch-data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "eecbedce-4a43-455a-994a-a9bf0129eb06",
#     "name": "batch-data",
#     "version": 1,
#     "description": "batch data",
#     "workspace": "Workspace.create(name='AML', subscription_id='a0d35038-9212-4eca-88f1-682726afa75c', resource_group='ML')"
#   }
# }
# Mounting diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/wd/tmpzxrq1pht.
# Mounted diabetes_batch to /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/wd/tmpzxrq1pht as folder.
# Exit __enter__ of DatasetContextManager
# Set Dataset diabetes_batch's target path to /mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/wd/tmpzxrq1pht
# Starting the daemon thread to refresh tokens in background for process with pid = 1
# Acquired lockfile /tmp/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3-datastore.lock to downloading input data references
# [2021-03-21T06:19:17.794321] INFO azureml.sidecar.task.enter_contexts: Entered Context Managers
# [2021-03-21T06:19:18.749999] Ran Sidecar prep cmd.
# [2021-03-21T06:19:18.750115] Running Context Managers in Sidecar complete.
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# 2021/03/21 06:20:15 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/info
# 2021/03/21 06:20:15 Attempt 1 of http call to http://10.0.0.4:16384/sendlogstoartifacts/status
# [2021-03-21T06:20:17.502443] Entering context manager injector.
# [context_manager_injector.py] Command line Options: Namespace(inject=['ProjectPythonPath:context_managers.ProjectPythonPath', 'Dataset:context_managers.Datasets', 'RunHistory:context_managers.RunHistory', 'TrackUserError:context_managers.TrackUserError'], invocation=['driver/amlbi_main.py', '--client_sdk_version', '1.24.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/mounts/workspaceblobstore/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/inferences', '--input_fds_0', 'diabetes_batch'])
# Script type = None
# Starting the daemon thread to refresh tokens in background for process with pid = 106
# [2021-03-21T06:20:19.839650] Entering Run History Context Manager.
# [2021-03-21T06:20:20.563205] Current directory: /mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/mounts/workspaceblobstore/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3
# [2021-03-21T06:20:20.563945] Preparing to call script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.24.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/mounts/workspaceblobstore/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/inferences', '--input_fds_0', 'diabetes_batch']
# [2021-03-21T06:20:20.564043] After variable expansion, calling script [driver/amlbi_main.py] with arguments:['--client_sdk_version', '1.24.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '/mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/mounts/workspaceblobstore/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/inferences', '--input_fds_0', 'diabetes_batch']
#
# 2021/03/21 06:20:20 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
#
# Streaming azureml-logs/75_job_post-tvmps_23c651f995573302fb40760c1ba8c3fa2d3edb749b1e89c4e2c3bf189841fcaa_d.txt
# ===============================================================================================================
# [2021-03-21T06:21:11.425283] Entering job release
# [2021-03-21T06:21:12.791736] Starting job release
# [2021-03-21T06:21:12.792513] Logging experiment finalizing status in history service.[2021-03-21T06:21:12.793242] job release stage : upload_datastore starting...
#
# [2021-03-21T06:21:12.793497] job release stage : start importing azureml.history._tracking in run_history_release.
# Starting the daemon thread to refresh tokens in background for process with pid = 278
# [2021-03-21T06:21:12.793754] job release stage : execute_job_release starting...
# [2021-03-21T06:21:12.794114] job release stage : copy_batchai_cached_logs starting...
# [2021-03-21T06:21:12.794149] job release stage : copy_batchai_cached_logs completed...
# [2021-03-21T06:21:12.868277] Entering context manager injector.
# [2021-03-21T06:21:12.998069] job release stage : send_run_telemetry starting...
# [2021-03-21T06:21:13.036313] job release stage : execute_job_release completed...
# [2021-03-21T06:21:13.042063] job release stage : upload_datastore completed...
# [2021-03-21T06:21:13.231763] get vm size and vm region successfully.
# [2021-03-21T06:21:13.250216] get compute meta data successfully.
# [2021-03-21T06:21:13.427671] post artifact meta request successfully.
# [2021-03-21T06:21:13.459390] upload compute record artifact successfully.
# [2021-03-21T06:21:13.688315] job release stage : send_run_telemetry completed...
# [2021-03-21T06:21:13.689189] Running in AzureML-Sidecar, starting to exit user context managers...
# [2021-03-21T06:21:13.689354] Running Sidecar release cmd...
# [2021-03-21T06:21:13.701159] INFO azureml.sidecar.sidecar: Received task: exit_contexts. Running on Linux at /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/mounts/workspaceblobstore/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3
# Enter __exit__ of DatasetContextManager
# Unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/wd/tmpzxrq1pht.
# Finishing unmounting /mnt/hostfs/mnt/batch/tasks/shared/LS_root/jobs/aml/azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/wd/tmpzxrq1pht.
# Exit __exit__ of DatasetContextManager
# [2021-03-21T06:21:13.921070] Removing absolute paths from host...
# [2021-03-21T06:21:14.067004] INFO azureml.sidecar.task.exit_contexts: Exited Context Managers
# [2021-03-21T06:21:14.795630] Ran Sidecar release cmd.
# [2021-03-21T06:21:14.795707] Job release is complete
#
# StepRun(batch-score-diabetes) Execution Summary
# ================================================
# StepRun( batch-score-diabetes ) Status: Finished
# {'runId': '066d8ae7-bf96-4d5e-8067-0dd8517f8dd3', 'target': 'LC-ML-Cluster-1', 'status': 'Completed', 'startTimeUtc': '2021-03-21T06:18:05.617398Z', 'endTimeUtc': '2021-03-21T06:21:41.749709Z', 'properties': {'ContentSnapshotId': '6a6b8504-4a70-4145-8d4e-f16a0ee50342', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '627cce5c-42bb-4523-88bf-199d3fb41bb6', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '189c86ea', 'azureml.pipelinerunid': '26b45430-816f-4c0f-ba40-9a1fa7e598d4', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'azureml.parallelrunstep': 'true'}, 'inputDatasets': [{'dataset': {'id': 'eecbedce-4a43-455a-994a-a9bf0129eb06'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'diabetes_batch', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'driver/amlbi_main.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--client_sdk_version', '1.24.0', '--scoring_module_name', 'batch_diabetes.py', '--mini_batch_size', '5', '--error_threshold', '10', '--output_action', 'append_row', '--logging_level', 'INFO', '--run_invocation_timeout', '60', '--run_max_try', '3', '--create_snapshot_at_runtime', 'True', '--output', '$AZUREML_DATAREFERENCE_inferences', '--input_fds_0', 'diabetes_batch'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'LC-ML-Cluster-1', 'dataReferences': {'inferences': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/066d8ae7-bf96-4d5e-8067-0dd8517f8dd3/inferences', 'pathOnCompute': 'diabetes/results', 'overwrite': False}}, 'data': {'diabetes_batch': {'dataLocation': {'dataset': {'id': 'eecbedce-4a43-455a-994a-a9bf0129eb06', 'name': None, 'version': '1'}, 'dataPath': None}, 'mechanism': 'Mount', 'environmentVariableName': 'diabetes_batch', 'pathOnCompute': None, 'overwrite': False}}, 'outputData': {}, 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 2, 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'batch_environment', 'version': 'Autosave_2021-03-21T06:06:28Z_896c6183', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults', 'azureml-core', 'azureml-dataprep[fuse]']}, 'scikit-learn', 'pip'], 'name': 'azureml_15a07964bce25243e0b7e62a107037d2'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/intelmpi2018.3-ubuntu16.04:20210220.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': None, 'imageVersion': None, 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useD ...
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '26b45430-816f-4c0f-ba40-9a1fa7e598d4', 'status': 'Completed', 'startTimeUtc': '2021-03-21T06:05:23.920327Z', 'endTimeUtc': '2021-03-21T06:21:45.354192Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://aml1914939045.blob.core.windows.net/azureml/ExperimentRun/dcid.26b45430-816f-4c0f-ba40-9a1fa7e598d4/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=T9l%2Bkx7rfHndiI%2Bm9daSvUEjYZ1LPsx%2F66JXv5pCjxY%3D&st=2021-03-21T06%3A11%3A48Z&se=2021-03-21T14%3A21%3A48Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://aml1914939045.blob.core.windows.net/azureml/ExperimentRun/dcid.26b45430-816f-4c0f-ba40-9a1fa7e598d4/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=oYQ93v6Iq7LNoRDGEaFFheudtpg2odHgUT%2BdZ25dhf8%3D&st=2021-03-21T06%3A11%3A48Z&se=2021-03-21T14%3A21%3A48Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://aml1914939045.blob.core.windows.net/azureml/ExperimentRun/dcid.26b45430-816f-4c0f-ba40-9a1fa7e598d4/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=%2BzWUe4F1dKL1LrhhDpQ7M2rV4W3FWmOZ0cnK1%2B6Qj30%3D&st=2021-03-21T06%3A11%3A48Z&se=2021-03-21T14%3A21%3A48Z&sp=r'}, 'submittedBy': 'Liam Croash'}
# 'Finished'

# %% [markdown]
# When the pipeline has finished running, the resulting predictions will have been saved in the outputs of the experiment associated with the first (and only) step in the pipeline. You can retrieve it as follows:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     5.csv           1
# 1    50.csv           1
# 2    51.csv           0
# 3    52.csv           0
# 4    53.csv           0
# 5    45.csv           0
# 6    46.csv           0
# 7    47.csv           1
# 8    48.csv           0
# 9    49.csv           1
# 10   36.csv           0
# 11   37.csv           0
# 12   38.csv           0
# 13   39.csv           1
# 14    4.csv           0
# 15    1.csv           0
# 16   10.csv           1
# 17  100.csv           0
# 18   11.csv           0
# 19   12.csv           0

# %% [markdown]
# ## Publish the Pipeline and use its REST Interface
#
# Now that you have a working pipeline for batch inferencing, you can publish it and use a REST endpoint to run it from an application.

# %%
published_pipeline = pipeline_run.publish_pipeline(
    name='diabetes-batch-pipeline', description='Batch scoring of diabetes data', version='1.0')

published_pipeline
# Out:
# Pipeline(Name: diabetes-batch-pipeline,
# Id: 212c0c68-d430-4ace-bb95-35379f3ed870,
# Status: Active,
# Endpoint: https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/a0d35038-9212-4eca-88f1-682726afa75c/resourceGroups/ML/providers/Microsoft.MachineLearningServices/workspaces/AML/PipelineRuns/PipelineSubmit/212c0c68-d430-4ace-bb95-35379f3ed870)

# %% [markdown]
# Note that the published pipeline has an endpoint, which you can see in the Azure portal. You can also find it as a property of the published pipeline object:

# %%
rest_endpoint = published_pipeline.endpoint
print(rest_endpoint)
# Out:
# https://westeurope.api.azureml.ms/pipelines/v1.0/subscriptions/a0d35038-9212-4eca-88f1-682726afa75c/resourceGroups/ML/providers/Microsoft.MachineLearningServices/workspaces/AML/PipelineRuns/PipelineSubmit/212c0c68-d430-4ace-bb95-35379f3ed870

# %% [markdown]
# To use the endpoint, client applications need to make a REST call over HTTP. This request must be authenticated, so an authorization header is required. To test this out, we'll use the authorization header from your current connection to your Azure workspace, which you can get using the following code:
#
# > **Note**: A real application would require a service principal with which to be authenticated.

# %%
from azureml.core.authentication import InteractiveLoginAuthentication

interactive_auth = InteractiveLoginAuthentication()
auth_header = interactive_auth.get_authentication_header()
print('Authentication header ready.')
# Out:
# Authentication header ready.

# %% [markdown]
# Now we're ready to call the REST interface. The pipeline runs asynchronously, so we'll get an identifier back, which we can use to track the pipeline experiment as it runs:

# %%
import requests

rest_endpoint = published_pipeline.endpoint
response = requests.post(rest_endpoint, 
                         headers=auth_header, 
                         json={"ExperimentName": "mslearn-diabetes-batch"})
run_id = response.json()["Id"]
run_id
# Out:
# '96986d04-5e82-46b0-8a6d-b1db7f744c82'

# %% [markdown]
# Since we have the run ID, we can use the **RunDetails** widget to view the experiment as it runs:

# %%
from azureml.pipeline.core.run import PipelineRun
from azureml.widgets import RunDetails

published_pipeline_run = PipelineRun(ws.experiments['mslearn-diabetes-batch'], run_id)

# Block until the run completes
published_pipeline_run.wait_for_completion(show_output=True)
# Out:
# PipelineRunId: 96986d04-5e82-46b0-8a6d-b1db7f744c82
# Link to Azure Machine Learning Portal: https://ml.azure.com/experiments/mslearn-diabetes-batch/runs/96986d04-5e82-46b0-8a6d-b1db7f744c82?wsid=/subscriptions/a0d35038-9212-4eca-88f1-682726afa75c/resourcegroups/ML/workspaces/AML
# PipelineRun Status: NotStarted
# PipelineRun Status: Running
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '96986d04-5e82-46b0-8a6d-b1db7f744c82', 'status': 'Completed', 'startTimeUtc': '2021-03-21T06:21:55.366638Z', 'endTimeUtc': '2021-03-21T06:21:57.113176Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'Unavailable', 'runType': 'HTTP', 'azureml.parameters': '{}', 'azureml.pipelineid': '212c0c68-d430-4ace-bb95-35379f3ed870'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://aml1914939045.blob.core.windows.net/azureml/ExperimentRun/dcid.96986d04-5e82-46b0-8a6d-b1db7f744c82/logs/azureml/executionlogs.txt?sv=2019-02-02&sr=b&sig=mkukl%2BSrDJ%2BchGFie9xOGdu8uA%2Bls7VInJlejv9nv%2B4%3D&st=2021-03-21T06%3A11%3A57Z&se=2021-03-21T14%3A21%3A57Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://aml1914939045.blob.core.windows.net/azureml/ExperimentRun/dcid.96986d04-5e82-46b0-8a6d-b1db7f744c82/logs/azureml/stderrlogs.txt?sv=2019-02-02&sr=b&sig=50%2BixpudM8G15XVaT7X5yoYN0HempWEf9wXOHSiGR%2BQ%3D&st=2021-03-21T06%3A11%3A57Z&se=2021-03-21T14%3A21%3A57Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://aml1914939045.blob.core.windows.net/azureml/ExperimentRun/dcid.96986d04-5e82-46b0-8a6d-b1db7f744c82/logs/azureml/stdoutlogs.txt?sv=2019-02-02&sr=b&sig=vxqD3AGqD4FKVcONfDqyS2bXTtPLwyB1%2BBnBz6LHDII%3D&st=2021-03-21T06%3A11%3A57Z&se=2021-03-21T14%3A21%3A57Z&sp=r'}, 'submittedBy': 'Liam Croash'}
# 'Finished'

# %% [markdown]
# Wait for the pipeline run to complete, and then run the following cell to see the results.
#
# As before, the results are in the output of the first pipeline step:

# %%
import pandas as pd
import shutil

# Remove the local results folder if left over from a previous run
shutil.rmtree('diabetes-results', ignore_errors=True)

# Get the run for the first step and download its output
prediction_run = next(pipeline_run.get_children())
prediction_output = prediction_run.get_output_data('inferences')
prediction_output.download(local_path='diabetes-results')

# Traverse the folder hierarchy and find the results file
for root, dirs, files in os.walk('diabetes-results'):
    for file in files:
        if file.endswith('parallel_run_step.txt'):
            result_file = os.path.join(root,file)

# cleanup output format
df = pd.read_csv(result_file, delimiter=":", header=None)
df.columns = ["File", "Prediction"]

# Display the first 20 results
df.head(20)
# Out:
#        File  Prediction
# 0     5.csv           1
# 1    50.csv           1
# 2    51.csv           0
# 3    52.csv           0
# 4    53.csv           0
# 5    45.csv           0
# 6    46.csv           0
# 7    47.csv           1
# 8    48.csv           0
# 9    49.csv           1
# 10   36.csv           0
# 11   37.csv           0
# 12   38.csv           0
# 13   39.csv           1
# 14    4.csv           0
# 15    1.csv           0
# 16   10.csv           1
# 17  100.csv           0
# 18   11.csv           0
# 19   12.csv           0

# %% [markdown]
# Now you have a pipeline that can be used to batch process daily patient data.
#
# **More Information**: For more details about using pipelines for batch inferencing, see the [How to Run Batch Predictions](https://docs.microsoft.com/azure/machine-learning/how-to-run-batch-predictions) in the Azure Machine Learning documentation.
